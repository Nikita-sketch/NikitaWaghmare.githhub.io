# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita-sketch/NikitaWaghmare.githhub.io/blob/main/Image_to_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("Shrutika.jpeg")
#img = cv2.imread("Dog.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x789 at 0x7F0C965BC8D0>

# %%
#cv2_imshow(final_img)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=720x789 at 0x7F0C9554FAD0>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=720x789 at 0x7F0C9553FA10>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=720x789 at 0x7F0CA9A22D10>

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=720x789 at 0x7F0C9554F710>
